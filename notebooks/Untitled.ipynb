# %%
import random
class MyLLM:
    def __init__(self)->None:
        first = "llm created"
        print(first)
    def predict(self,prompt):
        response_list=[
            "lana del rey songs are sad",
            "Sptoify is a music platform",
            "i love coffeee",
            "diet coke is life"
        ]
        return {
            "response" : random.choice(response_list)
        }

# %%
chain = MyLLM()
# Out:
# llm created

# %%
chain.predict("heyy")
# Out:
# {'response': 'diet coke is life'}

# %%
class MyPromptTemplate:
    def __init__(self,template,input_variables):
        self.template = template
        self.input_variables = input_variables

    def format(self , input_dict : dict):
        return self.template.format(**input_dict)

# %%
template = MyPromptTemplate(
    template= "write a poem about {topic}",
    input_variables= ["topic"]
)

# %%
template.format({"topic":"moksh"})
# Out:
# 'write a poem about moksh'
